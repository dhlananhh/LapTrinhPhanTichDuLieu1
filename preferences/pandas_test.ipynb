# %%
import pandas as pd
import numpy as np

# %% [markdown]
# importing data from a .csv file into a pandas DataFrame using "read_csv()" function.

# %%
df = pd.read_csv('dulieuxettuyendaihoc.csv')
df
# Out:
#        MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0     SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1     SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2     SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3     SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4     SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# ..      ...  ...  ...  ...  ...  ...  ... ..  ..  ...      ...
# 95   SV0096  8.6  8.9  7.7  6.7  7.9  6.6  F NaN    1     5.25
# 96   SV0097  3.7  4.1  3.1  3.4  5.5  5.7  F NaN    1     5.25
# 97   SV0098  8.8  9.5  9.5  8.5  9.0  8.5  M NaN  2NT     7.00
# 98   SV0099  2.7  2.8  6.2  5.2  4.1  4.3  M NaN    1     5.00
# 99  SV00100  4.1  4.4  6.0  4.3  5.6  5.1  M NaN  2NT     5.25
#
#     TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0                3.25            4.50  A1  12/7/2018                  No
# ...

# %% [markdown]
# # UNDEFINED (DATA PREPARATION)

# %% [markdown]
# select only the desired columns and reassign the result back to df in order to change it permanently.

# %%
df = df[['T5','T6','GT','DT','KV','KT','NGONNGU','TOANLOGICPHANTICH','GIAIQUYETVANDE','NGAYTHI']]
df
# Out:
#      T5   T6 GT  DT   KV  KT  NGONNGU  TOANLOGICPHANTICH  GIAIQUYETVANDE  \
# 0   7.4  6.9  F NaN  2NT  A1     3.25               3.25            4.50
# 1   3.0  4.0  M NaN    1   C     6.00               4.00            3.50
# 2   4.8  5.7  M NaN    1   C     5.00               6.75            4.00
# 3   6.1  7.4  M NaN    1  D1     4.25               4.25            5.25
# 4   6.8  8.0  M NaN  2NT   A     4.25               4.50            5.00
# ..  ...  ... ..  ..  ...  ..      ...                ...             ...
# 95  7.9  6.6  F NaN    1   C     5.25               1.50            6.25
# 96  5.5  5.7  F NaN    1   C     5.25               3.75            4.75
# 97  9.0  8.5  M NaN  2NT   C     7.00               8.00            4.00
# 98  4.1  4.3  M NaN    1   C     5.00               3.50            5.50
# 99  5.6  5.1  M NaN  2NT   C     5.25               2.50            4.25
#
#       NGAYTHI
# 0   12/7/2018
# 1   12/7/2018
# 2   12/7/2018
# 3   12/7/2018
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   T5                 100 non-null    float64
#  1   T6                 100 non-null    float64
#  2   GT                 100 non-null    object
#  3   DT                 3 non-null      float64
#  4   KV                 100 non-null    object
#  5   KT                 100 non-null    object
#  6   NGONNGU            100 non-null    float64
#  7   TOANLOGICPHANTICH  100 non-null    float64
#  8   GIAIQUYETVANDE     100 non-null    float64
#  9   NGAYTHI            100 non-null    object
# dtypes: float64(6), object(4)
# memory usage: 7.9+ KB

# %%
df.rename(columns={'TOANLOGICPHANTICH': 'TOAN', 'GIAIQUYETVANDE': 'UNGXU'}, inplace=True)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10060\2241638933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'TOANLOGICPHANTICH': 'TOAN', 'GIAIQUYETVANDE': 'UNGXU'}, inplace=True)
#      T5   T6 GT  DT   KV  KT  NGONNGU  TOAN  UNGXU    NGAYTHI
# 0   7.4  6.9  F NaN  2NT  A1     3.25  3.25   4.50  12/7/2018
# 1   3.0  4.0  M NaN    1   C     6.00  4.00   3.50  12/7/2018
# 2   4.8  5.7  M NaN    1   C     5.00  6.75   4.00  12/7/2018
# 3   6.1  7.4  M NaN    1  D1     4.25  4.25   5.25  12/7/2018
# 4   6.8  8.0  M NaN  2NT   A     4.25  4.50   5.00  12/7/2018
# ..  ...  ... ..  ..  ...  ..      ...   ...    ...        ...
# 95  7.9  6.6  F NaN    1   C     5.25  1.50   6.25  7/20/2022
# 96  5.5  5.7  F NaN    1   C     5.25  3.75   4.75  7/20/2022
# ...

# %% [markdown]
# - dropna() function drops both missing data and NaN data (that's why its name is dropna() not dropnan() so that it can be more generic), the how= 'all' argument indicates that it should drop a row iff that row is fully null.
# - isnull() returns a DataFrame of Boolean (True if a cell is null and False otherwise).
# - the unfunc sum() sums up the amount of True value on the row axis (0) by default.
# </br> <i>we can see that only 'DT' column has null values (97 values).</i>

# %%
df.dropna(how='all', inplace=True)
df.isnull().sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10060\3613894285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(how='all', inplace=True)
# T5          0
# T6          0
# GT          0
# DT         97
# KV          0
# KT          0
# NGONNGU     0
# TOAN        0
# UNGXU       0
# NGAYTHI     0
# dtype: int64

# %%
df.drop_duplicates(inplace= True)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10060\2176094787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace= True)
#      T5   T6 GT  DT   KV  KT  NGONNGU  TOAN  UNGXU    NGAYTHI
# 0   7.4  6.9  F NaN  2NT  A1     3.25  3.25   4.50  12/7/2018
# 1   3.0  4.0  M NaN    1   C     6.00  4.00   3.50  12/7/2018
# 2   4.8  5.7  M NaN    1   C     5.00  6.75   4.00  12/7/2018
# 3   6.1  7.4  M NaN    1  D1     4.25  4.25   5.25  12/7/2018
# 4   6.8  8.0  M NaN  2NT   A     4.25  4.50   5.00  12/7/2018
# ..  ...  ... ..  ..  ...  ..      ...   ...    ...        ...
# 95  7.9  6.6  F NaN    1   C     5.25  1.50   6.25  7/20/2022
# 96  5.5  5.7  F NaN    1   C     5.25  3.75   4.75  7/20/2022
# 97  9.0  8.5  M NaN  2NT   C     7.00  8.00   4.00  7/20/2022
# ...

# %% [markdown]
# - df['NGONNGU'] returns the selected column as a panda Series
# - df[['NGONNGU']] on the other hand returns a DataFrame.

# %%
df['NGONNGU']
df[['NGONNGU']]
# Out:
#     NGONNGU
# 0      3.25
# 1      6.00
# 2      5.00
# 3      4.25
# 4      4.25
# ..      ...
# 95     5.25
# 96     5.25
# 97     7.00
# 98     5.00
# 99     5.25
#
# [100 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   T5       100 non-null    float64
#  1   T6       100 non-null    float64
#  2   GT       100 non-null    object
#  3   DT       3 non-null      float64
#  4   KV       100 non-null    object
#  5   KT       100 non-null    object
#  6   NGONNGU  100 non-null    float64
#  7   TOAN     100 non-null    float64
#  8   UNGXU    100 non-null    float64
#  9   NGAYTHI  100 non-null    object
# dtypes: float64(6), object(4)
# memory usage: 7.9+ KB

# %% [markdown]
# Select the 'DT' column and then fill any null value with the specified value 'KINH'

# %%
df['DT'].fillna('KINH', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   T5       100 non-null    float64
#  1   T6       100 non-null    float64
#  2   GT       100 non-null    object
#  3   DT       100 non-null    object
#  4   KV       100 non-null    object
#  5   KT       100 non-null    object
#  6   NGONNGU  100 non-null    float64
#  7   TOAN     100 non-null    float64
#  8   UNGXU    100 non-null    float64
#  9   NGAYTHI  100 non-null    object
# dtypes: float64(5), object(5)
# memory usage: 7.9+ KB
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10060\2696067701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DT'].fillna('KINH', inplace=True)

# %%
df
df['TBTOAN'] = (df['T5'] + df['T6'])/2  
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10060\3319620685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TBTOAN'] = (df['T5'] + df['T6'])/2
#      T5   T6 GT    DT   KV  KT  NGONNGU  TOAN  UNGXU    NGAYTHI  TBTOAN
# 0   7.4  6.9  F  KINH  2NT  A1     3.25  3.25   4.50  12/7/2018    7.15
# 1   3.0  4.0  M  KINH    1   C     6.00  4.00   3.50  12/7/2018    3.50
# 2   4.8  5.7  M  KINH    1   C     5.00  6.75   4.00  12/7/2018    5.25
# 3   6.1  7.4  M  KINH    1  D1     4.25  4.25   5.25  12/7/2018    6.75
# 4   6.8  8.0  M  KINH  2NT   A     4.25  4.50   5.00  12/7/2018    7.40
# ..  ...  ... ..   ...  ...  ..      ...   ...    ...        ...     ...
# 95  7.9  6.6  F  KINH    1   C     5.25  1.50   6.25  7/20/2022    7.25
# ...

# %% [markdown]
# This code below will create a Pandas series of Boolean values, which is also known as a "Boolean mask" (masks are used in combination with loc[] to perform some more powerful data manipulation)

# %%
df['TBTOAN'] < 5
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98     True
# 99    False
# Name: TBTOAN, Length: 100, dtype: bool

# %% [markdown]
# - df.loc['row_selector', 'column_selector']
# - In the code below, you apply the "mask" (row_selector) to filter out the rows meeting your criteria, and then assign the value of 'FAILED' to their corresponding values in 'XEPLOAI' column (Pandas creates a new column for you if it doesn't exist yet)

# %%
df.loc[df['TBTOAN'] < 5, 'XEPLOAI'] = 'FAILED'
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10060\1366793654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['TBTOAN'] < 5, 'XEPLOAI'] = 'FAILED'
#      T5   T6 GT    DT   KV  KT  NGONNGU  TOAN  UNGXU    NGAYTHI  TBTOAN  \
# 0   7.4  6.9  F  KINH  2NT  A1     3.25  3.25   4.50  12/7/2018    7.15
# 1   3.0  4.0  M  KINH    1   C     6.00  4.00   3.50  12/7/2018    3.50
# 2   4.8  5.7  M  KINH    1   C     5.00  6.75   4.00  12/7/2018    5.25
# 3   6.1  7.4  M  KINH    1  D1     4.25  4.25   5.25  12/7/2018    6.75
# 4   6.8  8.0  M  KINH  2NT   A     4.25  4.50   5.00  12/7/2018    7.40
# ..  ...  ... ..   ...  ...  ..      ...   ...    ...        ...     ...
# ...

# %% [markdown]
# - When selecting column from a DataFrame, remember that '[]' is used for single-column selection only, if you want to select multiple columns then '[[]]' is required.
# - head() specifies the first n rows that you want to display (5 by default).

# %%
df[['TBTOAN', 'XEPLOAI']].head()
# Out:
#    TBTOAN XEPLOAI
# 0    7.15     NaN
# 1    3.50  FAILED
# 2    5.25     NaN
# 3    6.75     NaN
# 4    7.40     NaN

# %% [markdown]
# - map() function is used to transform data (availble for both Series and DataFrame).
# - For example : <br>
# <pre>
#     original_series = pd.Series([1,2,3,4])
#     mapping_strategy = {1: 'one', 2: 'two', 3: 'three', 4: 'four'}
#     new_series = original_series.map(mapping_strategy)
# </pre>
# - Thus, the values stored in the new_series would be ['one', 'two', 'three', 'four'].

# %%
mapping_dict = {'A1':'G1','C':'G3','A':'G1','B':'G2'}
df['NHOMKT'] = df['KT'].map(mapping_dict)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10060\2573914507.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NHOMKT'] = df['KT'].map(mapping_dict)
#      T5   T6 GT    DT   KV  KT  NGONNGU  TOAN  UNGXU    NGAYTHI  TBTOAN  \
# 0   7.4  6.9  F  KINH  2NT  A1     3.25  3.25   4.50  12/7/2018    7.15
# 1   3.0  4.0  M  KINH    1   C     6.00  4.00   3.50  12/7/2018    3.50
# 2   4.8  5.7  M  KINH    1   C     5.00  6.75   4.00  12/7/2018    5.25
# 3   6.1  7.4  M  KINH    1  D1     4.25  4.25   5.25  12/7/2018    6.75
# 4   6.8  8.0  M  KINH  2NT   A     4.25  4.50   5.00  12/7/2018    7.40
# ..  ...  ... ..   ...  ...  ..      ...   ...    ...        ...     ...
# ...

# %% [markdown]
# - map() returns an iterator which is not compatible with a pandas series, so we need to use list() to convert it.
# - the arguments passed in the map() function must follow that specified order, so that they can be passed to the extraPlus() function orderly correctly.

# %%
def extraPlus(x: str, y: float) -> float:
    if((x == 'G1' or x == 'G2') and (y >= 5)):
        return 1
    else:
        return 0

df['DIEMCONG'] = list(map(extraPlus, df['NHOMKT'], df['TBTOAN']))
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10060\2838616702.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DIEMCONG'] = list(map(extraPlus, df['NHOMKT'], df['TBTOAN']))
#      T5   T6 GT    DT   KV  KT  NGONNGU  TOAN  UNGXU    NGAYTHI  TBTOAN  \
# 0   7.4  6.9  F  KINH  2NT  A1     3.25  3.25   4.50  12/7/2018    7.15
# 1   3.0  4.0  M  KINH    1   C     6.00  4.00   3.50  12/7/2018    3.50
# 2   4.8  5.7  M  KINH    1   C     5.00  6.75   4.00  12/7/2018    5.25
# 3   6.1  7.4  M  KINH    1  D1     4.25  4.25   5.25  12/7/2018    6.75
# 4   6.8  8.0  M  KINH  2NT   A     4.25  4.50   5.00  12/7/2018    7.40
# ..  ...  ... ..   ...  ...  ..      ...   ...    ...        ...     ...
# ...

# %% [markdown]
# # HEAT MAP

# %% [markdown]
# - <code>plt.figure(figsize=(10, 6))</code> helps you gain more control over your figure ie. the top-level container of your plot.<br>
# - <code>cmap= 'YlGbBu'</code> indicates the 3 colors to apply on the color bar in your heatmap ('YlGnBu' = 'Yellow Green Blue').<br>
# - <code>cbar_kws={'label': 'missing data'}</code> sets the title for the color bar.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(df.isna().transpose(), cmap='YlGnBu', cbar_kws={'label':'missing data'})
plt.show()

# %% [markdown]
# # COUNT PLOT

# %% [markdown]
# - countplot represents the observations of each values in a categorical data.
# - <code>x= 'DT'</code> specifies the column which you want to represent in the plot.

# %%
sns.countplot(data=df, x='DT')
# Out:
# <Axes: xlabel='DT', ylabel='count'>

# %%
sns.countplot(data=df, x='NHOMKT')
# Out:
# <Axes: xlabel='NHOMKT', ylabel='count'>

# %%
df['NHOMKT'].unique()

df.loc[df['NHOMKT']=='', 'NHOMKT'] = 'undefined'
df['NHOMKT'].unique()

sns.countplot(data=df, x='NHOMKT')
# Out:
# <Axes: xlabel='NHOMKT', ylabel='count'>

# %% [markdown]
# - The code is creating a count plot using Seaborn. It's using the data from the DataFrame df and plotting the count of occurrences for each unique value in the 'KT' column on the x-axis. Additionally, it's using the 'GT' column to differentiate the bars by color. This allows you to see the count of occurrences of each value in the 'KT' column, while also distinguishing them based on the values in the 'GT' column.
# - the term <strong>"hue"</strong> in data visualization is essentially borrowed from the domain of color theory, where it refers to the attribute of color that defines its identity on the color wheel, and it's used to visually differentiate between different categories or groups in data visualization.

# %%
sns.countplot(data=df, x='KT', hue='GT')
# Out:
# <Axes: xlabel='KT', ylabel='count'>

# %%
sns.countplot(data=df, x='KT', hue='KV')
# Out:
# <Axes: xlabel='KT', ylabel='count'>

# %% [markdown]
# # BAR PLOT

# %%
df['NGONNGU'].unique()
# Out:
# array([3.25, 6.  , 5.  , 4.25, 1.5 , 6.5 , 3.75, 3.5 , 4.  , 3.  , 6.75,
#        2.  , 2.5 , 2.75, 7.  , 4.75, 5.25, 4.5 , 2.25, 5.75, 1.25, 1.  ,
#        1.75, 6.25])

# %% [markdown]
# - By default, Seaborn barplot() uses the mean data of the y-axis.
# - Error bar is a graphical representation indicating the uncertainty of an estimate, it shows the range that the true data may lie on. The short the more accurate. You can determine whether an error bar is long or short by considering its length with the y-axis data range (ie. the gap between 2 ticks).
# - to put it together, you have a bar plot representing the average english grade according to gender.

# %%
sns.barplot(x='GT', y='NGONNGU', data=df)
# Out:
# <Axes: xlabel='GT', ylabel='NGONNGU'>

# %%
sns.barplot(x= 'NHOMKT', y= 'TOAN', data= df, errorbar= None)
# Out:
# <Axes: xlabel='NHOMKT', ylabel='TOAN'>

# %%
sns.barplot(x= 'GT', y= 'NGONNGU',  hue= 'KT', data= df, errorbar= None)
# Out:
# <Axes: xlabel='GT', ylabel='NGONNGU'>

# %%
sns.barplot(x= 'GT', y= 'NGONNGU', hue= 'KT', data= df, estimator= max, errorbar= None)
# Out:
# <Axes: xlabel='GT', ylabel='NGONNGU'>

# %% [markdown]
# - In the case below, you must use the max function provided by NumPy as the estimator. The reason is a little bit tricky, the max itself is a Python built-in function and in certain cases, it can't be as flexible as the np.max function as NumPy was developed to dedicate for complex analysis calculation (especially n-dimensional arrays).
# - If I don't use the "hue = 'KT'", the max function still works well because it can easily calculate the maximum value of each KV value (according to the NGONNGU values). But it starts to show its limit when we add the "hue= 'KT'", which is now more complex as for each value of 'KV', we also have sub-categories within it ('KT' in this case), you can see them as 3 two-dimensional arrays, in such a situation, np.max suits  best as it can calculate the maximum value for EACH row within the array.

# %%
sns.barplot(x= 'KV', y= 'NGONNGU', hue= 'KT', data= df, estimator= np.max, errorbar= None)
# Out:
# <Axes: xlabel='KV', ylabel='NGONNGU'>

# %% [markdown]
# # PIE CHART

# %% [markdown]
# - 'autopct' stands for 'atuto percentage', it indicates how the percentage figures in your piechart are displayed ('%f1.1%%', '%2.2f%%', ...).

# %%
gb = df.groupby('KT').agg(total=('KT', 'count'))

labels = gb.index 
data = list(gb['total'])
colors = sns.color_palette('pastel')

plt.pie(data, labels=labels, colors=colors, autopct='%1.1f%%')
plt.show()

gb
# Out:
#     total
# KT
# A      49
# A1      6
# B       9
# C      14
# D1     22

# %%
gb = df.groupby('KV').agg(total=('KV', 'count'))

labels = gb.index 
data = list(gb['total'])
colors = sns.color_palette('pastel')

plt.pie(data, labels=labels, colors=colors, autopct='%1.1f%%')
plt.show()

gb
# Out:
#      total
# KV
# 1       60
# 2       19
# 2NT     21

# %%
#piechart - thong ke ti le % tong DIEMCONg tren tung nhom KV
gb = df.groupby('KV')['DIEMCONG'].agg(['sum'])

data = list(gb['sum'])
labels = gb.index
colors = sns.color_palette('pastel')

plt.pie(data, labels= labels, colors= colors, autopct= '%1.1f%%')
plt.show()

# %%
gb = df.groupby('KV')['KV'].agg(['count', 'sum'])
gb
# Out:
#      count                                                sum
# KV
# 1       60  1111111111111111111111111111111111111111111111...
# 2       19                                2222222222222222222
# 2NT     21  2NT2NT2NT2NT2NT2NT2NT2NT2NT2NT2NT2NT2NT2NT2NT2...

# %% [markdown]
# # LINE PLOT

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a line plot
plt.plot(x, y, marker='*')  # You can customize the marker style

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Line Plot')

# Display the plot
plt.show()

# %%
sns.lineplot(x= 'NGAYTHI', y= 'NGONNGU', data= df, estimator= np.max, hue= 'GT')
# Out:
# <Axes: xlabel='NGAYTHI', ylabel='NGONNGU'>

# %%
import matplotlib.pyplot as plt

data = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

plt.boxplot(data)
plt.title("Box Plot of Data")
plt.xlabel("Data")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# # NOTE 8/25/2034 (DRAFT) - DATA ANALYSIS

# %%
#Standard Deviation

std= np.mean(np.abs(df['NGONNGU'] - np.mean(df['NGONNGU'])))
std
# Out:
# 1.1600000000000001

# %%
#hay tinh phan vi thu 9 trong thap phan vi (goi la p9) cho T5 va T6
df[['T5', 'T6']].quantile(0.9)

#hay tinh khoang range cho T5 va T6
df[['T5', 'T6']].max() - df[['T5', 'T6']].min()

#hay tinh khoang IQR cho T5 va T6

#Hay tinh do lech trung binh cho T5 va T6
np.mean(np.abs(df[['T5', 'T6']] - np.mean(df[['T5', 'T6']])))
# Out:
# 1.14492

# %%
#phuong sai
df['NGONNGU'].var()

#do lech chuan
df['NGONNGU'].std()
# Out:
# 1.424408436488423

# %%
#phuong phap su dung std de so sanh
# muc do bien dong cua hai hay nhieu bien so
#vd: hay so sanh muc do on dinh cua T5 va T6
print(df[['T5', 'T6']].mean())
print(df[['T5', 'T6']].std())
#Luu y: can dam bao T5, T6 cung he quy chieu (do do don vi so sanh) va gia tri trung binh T5 va T6 xap xi nhau.

# %%
df
# Out:
#      T5   T6 GT    DT   KV  KT  NGONNGU  TOAN  UNGXU    NGAYTHI  TBTOAN  \
# 0   7.4  6.9  F  KINH  2NT  A1     3.25  3.25   4.50  12/7/2018    7.15
# 1   3.0  4.0  M  KINH    1   C     6.00  4.00   3.50  12/7/2018    3.50
# 2   4.8  5.7  M  KINH    1   C     5.00  6.75   4.00  12/7/2018    5.25
# 3   6.1  7.4  M  KINH    1  D1     4.25  4.25   5.25  12/7/2018    6.75
# 4   6.8  8.0  M  KINH  2NT   A     4.25  4.50   5.00  12/7/2018    7.40
# ..  ...  ... ..   ...  ...  ..      ...   ...    ...        ...     ...
# 95  7.9  6.6  F  KINH    1   C     5.25  1.50   6.25  7/20/2022    7.25
# 96  5.5  5.7  F  KINH    1   C     5.25  3.75   4.75  7/20/2022    5.60
# 97  9.0  8.5  M  KINH  2NT   C     7.00  8.00   4.00  7/20/2022    8.75
# 98  4.1  4.3  M  KINH    1   C     5.00  3.50   5.50  7/20/2022    4.20
# 99  5.6  5.1  M  KINH  2NT   C     5.25  2.50   4.25  7/20/2022    5.35
#
#    XEPLOAI NHOMKT  DIEMCONG
# 0      NaN     G1         1
# 1   FAILED     G3         0
# ...

# %%
#Dung phuong phap Coefficient of Variance (CV) de do
#muc do bien dong cua 2 hay nhieu bien so
#Hay so sanh muc do bien dong cua LOGIC va NGONNGU
print( df[['NGONNGU', 'TOAN']].std() / df[['NGONNGU', 'TOAN']].mean() )
# Out:
# NGONNGU    0.380858
# TOAN       0.249131
# dtype: float64

# %%
df.groupby('GT')['NGONNGU'].describe()
# cau hoi : danh gia xem nhom gioi tinh nao thi tot hon mon ngoai ngu
# Out:
#     count      mean       std   min     25%   50%  75%  max
# GT
# F    48.0  3.854167  1.348594  1.25  3.1875  3.75  5.0  7.0
# M    52.0  3.634615  1.496288  1.00  2.4375  3.50  4.5  7.0

# %%
import matplotlib.pyplot as plt

# Sample data
data = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# Create a histogram
plt.hist(data, bins=5, edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Sample Data')

# Show the plot
plt.show()
