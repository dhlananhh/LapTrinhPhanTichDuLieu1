# %% [markdown]
# ĐỌC DỮ LIỆU

# %%
# Đọc dữ liệu

import pandas as pd
import numpy as np

df = pd.read_csv('../data/orginal_sales_data_edit.csv', encoding='utf-8', header=0,delimiter=',')

# %% [markdown]
# HIỂN THỊ BẢNG

# %%
# Hiển thị thông tin bảng 
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0      2/24/2003   Shipped       1         2     2003  ...          NaN
# 1       5/7/2003   Shipped       2         5     2003  ...          NaN
# 2       7/1/2003   Shipped       3         7     2003  ...          NaN
# 3      8/25/2003   Shipped       3         8     2003  ...          NaN
# 4     10/10/2003   Shipped       4        10     2003  ...          NaN
# ...          ...       ...     ...       ...      ...  ...          ...
# 2818   12/2/2004   Shipped       4        12     2004  ...          NaN
# 2819   1/31/2005   Shipped       1         1     2005  ...          NaN
# 2820    3/1/2005  Resolved       1         3     2005  ...          NaN
# 2821   3/28/2005   Shipped       1         3     2005  ...          NaN
# 2822    5/6/2005   On Hold       2         5     2005  ...          NaN
#
#                CITY STATE POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME  \
# 0               NYC    NY      10022      USA       NaN              Yu
# 1             Reims   NaN      51100   France      EMEA         Henriot
# 2             Paris   NaN      75508   France      EMEA        Da Cunha
# 3          Pasadena    CA      90003      USA       NaN           Young
# 4     San Francisco    CA        NaN      USA       NaN           Brown
# ...             ...   ...        ...      ...       ...             ...
# 2818         Madrid   NaN      28034    Spain      EMEA          Freyre
# 2819           Oulu   NaN      90110  Finland      EMEA       Koskitalo
# 2820         Madrid   NaN      28034    Spain      EMEA          Freyre
# 2821       Toulouse   NaN      31000   France      EMEA          Roulet
# 2822         Boston    MA      51003      USA       NaN         Yoshido
#
#      CONTACTFIRSTNAME DEALSIZE   PAYMENTFULLNAME
# 0                Kwai    Small           Yu Kwai
# 1                Paul    Small      Henriot Paul
# 2              Daniel   Medium    DaCunha Daniel
# 3               Julie   Medium       Young Julie
# 4               Julie   Medium       Brown Julie
# ...               ...      ...               ...
# 2818            Diego    Small      Freyre Diego
# 2819           Pirkko   Medium  Koskitalo Pirkko
# 2820            Diego   Medium      Freyre Diego
# 2821          Annette    Small    Roulet Annette
# 2822             Juri   Medium      Yoshido Juri
#
# [2823 rows x 28 columns]

# %%
# Đọc 10 dòng đầu
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
# 5  10/28/2003  Shipped       4        10     2003  ...          NaN
# 6  11/11/2003  Shipped       4        11     2003  ...          NaN
# 7  11/18/2003  Shipped       4        11     2003  ...          NaN
# 8   12/1/2003  Shipped       4        12     2003  ...          NaN
# 9   1/15/2004  Shipped       1         1     2004  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# 1          Reims   NaN      51100  France      EMEA         Henriot
# 2          Paris   NaN      75508  France      EMEA        Da Cunha
# 3       Pasadena    CA      90003     USA       NaN           Young
# 4  San Francisco    CA        NaN     USA       NaN           Brown
# 5     Burlingame    CA      94217     USA       NaN          Hirano
# 6          Lille   NaN      59000  France      EMEA           Rance
# 7         Bergen   NaN     N 5804  Norway      EMEA          Oeztan
# 8  San Francisco    CA        NaN     USA       NaN          Murphy
# 9          Paris   NaN      75016  France      EMEA         Perrier
#
#   CONTACTFIRSTNAME DEALSIZE    PAYMENTFULLNAME
# 0             Kwai    Small            Yu Kwai
# 1             Paul    Small       Henriot Paul
# 2           Daniel   Medium     DaCunha Daniel
# 3            Julie   Medium        Young Julie
# 4            Julie   Medium        Brown Julie
# 5             Juri   Medium        Hirano Juri
# 6          Martine    Small      Rance Martine
# 7           Veysel   Medium      Oeztan Veysel
# 8            Julie    Small       Murphy Julie
# 9        Dominique   Medium  Perrier Dominique
#
# [10 rows x 28 columns]

# %%
# Đọc 10 dòng cuối
df.tail(10)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2813        10293               32      60.06                1  1921.92
# 2814        10306               35      59.51                6  2082.85
# 2815        10315               40      55.69                5  2227.60
# 2816        10327               37      86.74                4  3209.38
# 2817        10337               42      97.16                5  4080.72
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 2813    9/9/2004   Shipped       3         9     2004  ...          NaN
# 2814  10/14/2004   Shipped       4        10     2004  ...          NaN
# 2815  10/29/2004   Shipped       4        10     2004  ...          NaN
# 2816  11/10/2004  Resolved       4        11     2004  ...          NaN
# 2817  11/21/2004   Shipped       4        11     2004  ...    Suite 750
# 2818   12/2/2004   Shipped       4        12     2004  ...          NaN
# 2819   1/31/2005   Shipped       1         1     2005  ...          NaN
# 2820    3/1/2005  Resolved       1         3     2005  ...          NaN
# 2821   3/28/2005   Shipped       1         3     2005  ...          NaN
# 2822    5/6/2005   On Hold       2         5     2005  ...          NaN
#
#             CITY STATE POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME  \
# 2813      Torino   NaN      10100    Italy      EMEA         Accorti
# 2814  Manchester   NaN    EC2 5NT       UK      EMEA        Ashworth
# 2815      Nantes   NaN      44000   France      EMEA         Labrune
# 2816   Kobenhavn   NaN       1734  Denmark      EMEA        Petersen
# 2817         NYC    NY      10022      USA       NaN       Hernandez
# 2818      Madrid   NaN      28034    Spain      EMEA          Freyre
# 2819        Oulu   NaN      90110  Finland      EMEA       Koskitalo
# 2820      Madrid   NaN      28034    Spain      EMEA          Freyre
# 2821    Toulouse   NaN      31000   France      EMEA          Roulet
# 2822      Boston    MA      51003      USA       NaN         Yoshido
#
#      CONTACTFIRSTNAME DEALSIZE    PAYMENTFULLNAME
# 2813            Paolo    Small      Accorti Paolo
# 2814         Victoria    Small  Ashworth Victoria
# 2815           Janine    Small     Labrune Janine
# 2816            Jytte   Medium     Petersen Jytte
# 2817            Maria   Medium    Hernandez Maria
# 2818            Diego    Small       Freyre Diego
# 2819           Pirkko   Medium   Koskitalo Pirkko
# 2820            Diego   Medium       Freyre Diego
# 2821          Annette    Small     Roulet Annette
# 2822             Juri   Medium       Yoshido Juri
#
# [10 rows x 28 columns]

# %%
# tạo ra 1 tóm tắt thống kê cho dữ liệu DataFrame
"""
df.describe() sẽ tính toán các thống kê quan trọng cho từng cột trong DataFrame
"""

df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# 25%     2203.430000     2.000000     4.000000  2003.00000    68.000000
# 50%     3184.800000     3.000000     8.000000  2004.00000    99.000000
# 75%     4508.000000     4.000000    11.000000  2004.00000   124.000000
# max    14082.800000     4.000000    12.000000  2005.00000   214.000000

# %% [markdown]
# TỔNG QUAN DỮ LIỆU

# %%
"""
Xem thông tin định dạng và số lượng quan sát non-null của mỗi trường trong DataFrame
"""

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CATEGORY          2823 non-null   object
#  14  SUBCATEGORY       2823 non-null   object
#  15  CUSTOMERNAME      2823 non-null   object
#  16  PHONE             2823 non-null   object
#  17  ADDRESSLINE1      2823 non-null   object
#  18  ADDRESSLINE2      302 non-null    object
#  19  CITY              2823 non-null   object
#  20  STATE             1337 non-null   object
#  21  POSTALCODE        2747 non-null   object
#  22  COUNTRY           2823 non-null   object
#  23  TERRITORY         1749 non-null   object
#  24  CONTACTLASTNAME   2823 non-null   object
#  25  CONTACTFIRSTNAME  2823 non-null   object
#  26  DEALSIZE          2823 non-null   object
#  27  PAYMENTFULLNAME   2823 non-null   object
# dtypes: float64(2), int64(7), object(19)
# memory usage: 617.7+ KB

# %% [markdown]
# KIỂM TRA CẤU TRÚC CHỈ MỤC DỮ LIỆU

# %%
# Kiểm tra cấu trúc chỉ mục dữ liệu

df.index
# Out:
# RangeIndex(start=0, stop=2823, step=1)

# %% [markdown]
# KIỂM TRA BAO NHIÊU DÒNG, CỘT

# %%
# Kt bnhiu dòng, cột

df.shape

"""
28 cột
2823 dòng
"""
# Out:
# '\n28 cột\n2823 dòng\n'

# %% [markdown]
# KIỂM TRA KIỂU DỮ LIỆU

# %%
# Kt kiểu dữ liệu của cột YEAR_ID

df["YEAR_ID"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# CHUYỂN ĐỔI DỮ LIỆU TỪ int64 SANG int32

# %%
# Chuyển đổi dữ liệu từ int64 sang int32

df["YEAR_ID"] = df["YEAR_ID"].astype("int32")

# %%
# Kt kiểu dữ liệu của cột YEAR_ID

df["YEAR_ID"].dtype
# Out:
# dtype('int32')

# %% [markdown]
# LOẠI BỎ CÁC DÒNG CÓ GIÁ TRỊ NaN

# %%
# Loại bỏ các dòng có giá trị NaN

df.dropna(how='all', inplace=True)

# Hiển thị từ dòng đầu tiên đến dòng thứ 10
df[:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
# 5  10/28/2003  Shipped       4        10     2003  ...          NaN
# 6  11/11/2003  Shipped       4        11     2003  ...          NaN
# 7  11/18/2003  Shipped       4        11     2003  ...          NaN
# 8   12/1/2003  Shipped       4        12     2003  ...          NaN
# 9   1/15/2004  Shipped       1         1     2004  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# 1          Reims   NaN      51100  France      EMEA         Henriot
# 2          Paris   NaN      75508  France      EMEA        Da Cunha
# 3       Pasadena    CA      90003     USA       NaN           Young
# 4  San Francisco    CA        NaN     USA       NaN           Brown
# 5     Burlingame    CA      94217     USA       NaN          Hirano
# 6          Lille   NaN      59000  France      EMEA           Rance
# 7         Bergen   NaN     N 5804  Norway      EMEA          Oeztan
# 8  San Francisco    CA        NaN     USA       NaN          Murphy
# 9          Paris   NaN      75016  France      EMEA         Perrier
#
#   CONTACTFIRSTNAME DEALSIZE    PAYMENTFULLNAME
# 0             Kwai    Small            Yu Kwai
# 1             Paul    Small       Henriot Paul
# 2           Daniel   Medium     DaCunha Daniel
# 3            Julie   Medium        Young Julie
# 4            Julie   Medium        Brown Julie
# 5             Juri   Medium        Hirano Juri
# 6          Martine    Small      Rance Martine
# 7           Veysel   Medium      Oeztan Veysel
# 8            Julie    Small       Murphy Julie
# 9        Dominique   Medium  Perrier Dominique
#
# [10 rows x 28 columns]

# %% [markdown]
# LOẠI BỎ CÁC DÒNG CÓ GIÁ TRỊ TRÙNG LẶP

# %%
# Loại bỏ các dòng có giá trị trùng lặp

df.drop_duplicates(inplace=True)

# %% [markdown]
# TÍNH SỐ LƯỢNG CÁC DÒNG CÓ GIÁ TRỊ NaN TRONG CỘT "ADDRESSLINE2"

# %%
# Tính số lượng các dòng có giá trị NaN trong cột "ADDRESSLINE2"

df["ADDRESSLINE2"].isna().sum()
# Out:
# 2521

# %% [markdown]
# THAY THẾ TẤT CẢ CÁC DÒNG CÓ GIÁ TRỊ NaN TRONG CỘT "ADDRESSLINE2" BẰNG CHUỖI 'Unknown'

# %%
# Thay thế tất cả các dòng có giá trị NaN trong cột "ADDRESSLINE2" bằng chuỗi 'Unknown'

df["ADDRESSLINE2"].fillna('Unknown', inplace=True)
df['ADDRESSLINE2']

# %% [markdown]
# DẠNG SERIES

# %%
# Lấy dữ liệu theo cột dạng chuỗi

df['QUANTITYORDERED']
# Out:
# 0       30
# 1       34
# 2       41
# 3       45
# 4       49
#         ..
# 2818    20
# 2819    29
# 2820    43
# 2821    34
# 2822    47
# Name: QUANTITYORDERED, Length: 2823, dtype: int64

# %% [markdown]
# DẠNG MẢNG

# %%
# Lấy dữ liệu về 1 mảng

df['QUANTITYORDERED'].values
# Out:
# array([30, 34, 41, ..., 43, 34, 47], dtype=int64)

# %% [markdown]
# DẠNG DATAFRAME

# %%
df[['QUANTITYORDERED']]
# Out:
#       QUANTITYORDERED
# 0                  30
# 1                  34
# 2                  41
# 3                  45
# 4                  49
# ...               ...
# 2818               20
# 2819               29
# 2820               43
# 2821               34
# 2822               47
#
# [2823 rows x 1 columns]

# %% [markdown]
# GỘP CỘT TRẢ VỀ DẠNG DATAFRAME

# %%
df[['QUANTITYORDERED', 'ORDERNUMBER', 'PRICEEACH']]
# Out:
#       QUANTITYORDERED  ORDERNUMBER  PRICEEACH
# 0                  30        10107      95.70
# 1                  34        10121      81.35
# 2                  41        10134      94.74
# 3                  45        10145      83.26
# 4                  49        10159     100.00
# ...               ...          ...        ...
# 2818               20        10350     100.00
# 2819               29        10373     100.00
# 2820               43        10386     100.00
# 2821               34        10397      62.24
# 2822               47        10414      65.52
#
# [2823 rows x 3 columns]

# %%
df[['QUANTITYORDERED', 'PRICEEACH', 'SALES', 'MSRP']]
# Out:
#       QUANTITYORDERED  PRICEEACH    SALES  MSRP
# 0                  30      95.70  2871.00    95
# 1                  34      81.35  2765.90    95
# 2                  41      94.74  3884.34    95
# 3                  45      83.26  3746.70    95
# 4                  49     100.00  5205.27    95
# ...               ...        ...      ...   ...
# 2818               20     100.00  2244.40    54
# 2819               29     100.00  3978.51    54
# 2820               43     100.00  5417.57    54
# 2821               34      62.24  2116.16    54
# 2822               47      65.52  3079.44    54
#
# [2823 rows x 4 columns]

# %% [markdown]
# TẠO CỘT MỚI VÀ TRẢ VỀ BẢNG DATAFRAME

# %%
# Tạo cột mới và trả về bảng DataFrame
# Tạo 1 cột mới có tên là TOTALPRICE
# Giá trị TOTALPRICE = Giá trị QUANTITYORDERED * Giá trị PRICEEACH

df['TOTALPRICE'] = df['QUANTITYORDERED'] * df['PRICEEACH']

# %%
# Kiểm tra cột TOTALPRICE sau khi tạo mới

df[['TOTALPRICE']]
# Out:
#       TOTALPRICE
# 0        2871.00
# 1        2765.90
# 2        3884.34
# 3        3746.70
# 4        4900.00
# ...          ...
# 2818     2000.00
# 2819     2900.00
# 2820     4300.00
# 2821     2116.16
# 2822     3079.44
#
# [2823 rows x 1 columns]

# %%
# Tạo 1 cột mới có tên là FULLNAME
# Dữ liệu "FULLNAME" = "CONTACTLASTNAME" + " " + "CONTACTFIRSTNAME"

# %%
df['FULLNAME'] = df['CONTACTLASTNAME'] + ' ' + df['CONTACTFIRSTNAME']

# %%
# Kiểm tra cột FULLNAME sau khi tạo

df[['FULLNAME']]
# Out:
#               FULLNAME
# 0              Yu Kwai
# 1         Henriot Paul
# 2      Da Cunha Daniel
# 3          Young Julie
# 4          Brown Julie
# ...                ...
# 2818      Freyre Diego
# 2819  Koskitalo Pirkko
# 2820      Freyre Diego
# 2821    Roulet Annette
# 2822      Yoshido Juri
#
# [2823 rows x 1 columns]

# %% [markdown]
# LẤY DỮ LIỆU THEO DÒNG

# %%
df[4:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... STATE  POSTALCODE  \
# 4  10/10/2003  Shipped       4        10     2003  ...    CA         NaN
# 5  10/28/2003  Shipped       4        10     2003  ...    CA       94217
# 6  11/11/2003  Shipped       4        11     2003  ...   NaN       59000
# 7  11/18/2003  Shipped       4        11     2003  ...   NaN      N 5804
# 8   12/1/2003  Shipped       4        12     2003  ...    CA         NaN
# 9   1/15/2004  Shipped       1         1     2004  ...   NaN       75016
#
#   COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE  \
# 4     USA       NaN           Brown            Julie   Medium
# 5     USA       NaN          Hirano             Juri   Medium
# 6  France      EMEA           Rance          Martine    Small
# 7  Norway      EMEA          Oeztan           Veysel   Medium
# 8     USA       NaN          Murphy            Julie    Small
# 9  France      EMEA         Perrier        Dominique   Medium
#
#      PAYMENTFULLNAME TOTALPRICE           FULLNAME
# 4        Brown Julie    4900.00        Brown Julie
# 5        Hirano Juri    3479.76        Hirano Juri
# 6      Rance Martine    2497.77      Rance Martine
# 7      Oeztan Veysel    4800.00      Oeztan Veysel
# 8       Murphy Julie    2168.54       Murphy Julie
# 9  Perrier Dominique    4100.00  Perrier Dominique
#
# [6 rows x 30 columns]
