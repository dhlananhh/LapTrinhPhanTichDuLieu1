# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

df = pd.read_csv('BT_Tuan3\BH.csv')
df
# Out:
#     User_ID Product_ID  Purchase
# 0      1001         P1       100
# 1      1001         P2       200
# 2      1001         P3       300
# 3      1001         P4       500
# 4      1002         P2       200
# 5      1003         P3       400
# 6      1004         P1       200
# 7      1004         P2       300
# 8      1004         P3       400
# 9      1004         P4       500
# 10     1005         P1       100
# 11     1005         P2       200
# 12     1005         P3       300
# 13     1005         P4       400
# 14     1005         P5       500

# %% [markdown]
# 3.Đọc File với các tuỳ chọn mặc định. Hiển thị 5 dòng dữ liệu đầu tiên

# %%
df = pd.read_csv('BT_Tuan3\BH.csv').head(5)
df
# Out:
#    User_ID Product_ID  Purchase
# 0     1001         P1     100.0
# 1     1001         P2     200.0
# 2     1001         P3     300.0
# 3     1001         P4     500.0
# 4     1002         P2     200.0

# %% [markdown]
# 4.	Đọc File với các tuỳ chọn mặc định. Hiển thị 5 dòng dữ liệu cuối cùng

# %%
df = pd.read_csv('BT_Tuan3\BH.csv').tail(5)
df
# Out:
#     User_ID Product_ID  Purchase
# 11     1005         P2     200.0
# 12     1005         P3     300.0
# 13     1005         P4     400.0
# 14     1005         P5     500.0
# 15     1002         P3       NaN

# %% [markdown]
# 5.	Chuyển kiểu dữ liệu cho 1 cột nào đó

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15 non-null     int64
#  1   Product_ID  15 non-null     object
#  2   Purchase    15 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 488.0+ bytes

# %%
# chuyển kiểu dữ liệu của cột Purchase hiện tại là int64 sang int32
df['Purchase'] = df['Purchase'].astype('int32')
df.head(5)
# Out:
#    User_ID Product_ID  Purchase
# 0     1001         P1       100
# 1     1001         P2       200
# 2     1001         P3       300
# 3     1001         P4       500
# 4     1002         P2       200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15 non-null     int64
#  1   Product_ID  15 non-null     object
#  2   Purchase    15 non-null     int32
# dtypes: int32(1), int64(1), object(1)
# memory usage: 428.0+ bytes

# %% [markdown]
# 6.	Xem chiều dài của df, tương đương shape[0]
# print('Len:', len(df))

# %%
print('Len:', len(df))
# Out:
# Len: 15

# %% [markdown]
# 7.	Xem thông tin dataframe vừa đọc được
# df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15 non-null     int64
#  1   Product_ID  15 non-null     object
#  2   Purchase    15 non-null     int32
# dtypes: int32(1), int64(1), object(1)
# memory usage: 428.0+ bytes

# %% [markdown]
# 8.	Xem kích thước của dataframe
# print('Shape:', df.shape)

# %%
print('Shape:',df.shape)
# Out:
# Shape: (15, 3)

# %% [markdown]
# 9.	Hiển thị dữ liệu của cột thứ 3
# df[‘tên cột’]

# %%
df['Purchase']
# Out:
# 0     100
# 1     200
# 2     300
# 3     500
# 4     200
# 5     400
# 6     200
# 7     300
# 8     400
# 9     500
# 10    100
# 11    200
# 12    300
# 13    400
# 14    500
# Name: Purchase, dtype: int32

# %% [markdown]
# 10.	Hiển thị dữ liệu của cột 1,2,3,5,6
# df[['Tên cột 1', 'Tên cột 2', 'Tên cột 3']]

# %%
df[['User_ID','Purchase','Product_ID']]
# Out:
#     User_ID  Purchase Product_ID
# 0      1001       100         P1
# 1      1001       200         P2
# 2      1001       300         P3
# 3      1001       500         P4
# 4      1002       200         P2
# 5      1003       400         P3
# 6      1004       200         P1
# 7      1004       300         P2
# 8      1004       400         P3
# 9      1004       500         P4
# 10     1005       100         P1
# 11     1005       200         P2
# 12     1005       300         P3
# 13     1005       400         P4
# 14     1005       500         P5

# %% [markdown]
# 11.	Hiển thị 5 dòng dữ liệu đầu tiên gồm các cột 1,2,3,5,6
# df[['Tên cột 1', 'Tên cột 2', 'Tên cột 3']].head[5]

# %%
df[['User_ID','Purchase','Product_ID']].head(5)
# Out:
#    User_ID  Purchase Product_ID
# 0     1001       100         P1
# 1     1001       200         P2
# 2     1001       300         P3
# 3     1001       500         P4
# 4     1002       200         P2

# %% [markdown]
# 12.	Hiển thị 5 dòng dữ liệu đầu tiên theo chỉ số
# df[0:5]

# %%
df[0:5]
# Out:
#    User_ID Product_ID  Purchase
# 0     1001         P1       100
# 1     1001         P2       200
# 2     1001         P3       300
# 3     1001         P4       500
# 4     1002         P2       200

# %% [markdown]
# 13.	Hiển thị 5 dòng dữ liệu đầu tiên theo chỉ số gồm các cột 1,2,3,5,6
# df[['Tên cột 1', 'Tên cột 2', 'Tên cột 3']][:5]

# %%
df[['User_ID','Purchase','Product_ID']][:5]
# Out:
#    User_ID  Purchase Product_ID
# 0     1001       100         P1
# 1     1001       200         P2
# 2     1001       300         P3
# 3     1001       500         P4
# 4     1002       200         P2

# %% [markdown]
# 14.	Loại bỏ các dòng trùng nhau
# df.drop_duplicates(inplace=True)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#     User_ID Product_ID  Purchase
# 0      1001         P1       100
# 1      1001         P2       200
# 2      1001         P3       300
# 3      1001         P4       500
# 4      1002         P2       200
# 5      1003         P3       400
# 6      1004         P1       200
# 7      1004         P2       300
# 8      1004         P3       400
# 9      1004         P4       500
# 10     1005         P1       100
# 11     1005         P2       200
# 12     1005         P3       300
# 13     1005         P4       400
# 14     1005         P5       500

# %% [markdown]
# 15.	Loại bỏ các dòng trống có dữ liệu của 1 cột là trống
# df['ADDRESSLINE2'].isna().sum()

# %%
df['User_ID'].isna().sum()
# Out:
# 0

# %% [markdown]
# 16.	Loại bỏ các dòng của 1 cột có giá trị là không biết (“unknown”)
# df["ADDRESSLINE2"].fillna('Unknown',inplace=True)
# df['ADDRESSLINE2'].isna().sum()

# %%
df["Purchase"].fillna('Unknown',inplace=True)
df['Purchase'].isna().sum()
# Out:
# 0

# %% [markdown]
# 17.	Lấy dữ liệu của 1 cột theo dạng chuỗi
# df["QUANTITYORDERED"]

# %%
df["Purchase"]
# Out:
# 0     100
# 1     200
# 2     300
# 3     500
# 4     200
# 5     400
# 6     200
# 7     300
# 8     400
# 9     500
# 10    100
# 11    200
# 12    300
# 13    400
# 14    500
# Name: Purchase, dtype: int32

# %% [markdown]
# 18.	Lấy dữ liệu của 1 cột về một mảng
# df["QUANTITYORDERED"].values

# %%
df["Purchase"].values
# Out:
# array([100, 200, 300, 500, 200, 400, 200, 300, 400, 500, 100, 200, 300,
#        400, 500])

# %% [markdown]
# 19.	Lấy dữ liệu của 1 cột về một mảng
# df["QUANTITYORDERED"].values

# %%
df["Purchase"].values
# Out:
# array([100, 200, 300, 500, 200, 400, 200, 300, 400, 500, 100, 200, 300,
#        400, 500])

# %% [markdown]
# 20.	Lấy dữ liệu từ dòng số 4 đến dòng 9
# df[4:10]

# %%
df[4:10]
# Out:
#    User_ID Product_ID  Purchase
# 4     1002         P2       200
# 5     1003         P3       400
# 6     1004         P1       200
# 7     1004         P2       300
# 8     1004         P3       400
# 9     1004         P4       500

# %% [markdown]
# 21.	Đọc dữ liệu từ dòng 4 đến dòng 9
# df.loc[4:10]
# df.iloc[4:10]

# %%
df.loc[4:9]
# Out:
#    User_ID Product_ID  Purchase
# 4     1002         P2       200
# 5     1003         P3       400
# 6     1004         P1       200
# 7     1004         P2       300
# 8     1004         P3       400
# 9     1004         P4       500

# %%
df.iloc[4:10]
# Out:
#    User_ID Product_ID  Purchase
# 4     1002         P2       200
# 5     1003         P3       400
# 6     1004         P1       200
# 7     1004         P2       300
# 8     1004         P3       400
# 9     1004         P4       500

# %% [markdown]
# 22.	Lấy thông tin tại dòng có chỉ số là 2
# df.loc[2]

# %%
df.loc[2]
# Out:
# User_ID       1001
# Product_ID      P3
# Purchase       300
# Name: 2, dtype: object

# %% [markdown]
# 23.	Lấy thông tin từ dòng 4 đến dòng 10 của một số cột
# df.loc[4:10,['QUANTITYORDERED','SALES']]

# %%
df.loc[4:10,['User_ID','Product_ID']]
# Out:
#     User_ID Product_ID
# 4      1002         P2
# 5      1003         P3
# 6      1004         P1
# 7      1004         P2
# 8      1004         P3
# 9      1004         P4
# 10     1005         P1

# %% [markdown]
# 24.	Lấy thông tin dòng 2 đến dòng 9, từ cột 4 đến cột 7
# df.iloc[2:9,4:7]

# %%
df.iloc[2:9,1:3]
# Out:
#   Product_ID  Purchase
# 2         P3       300
# 3         P4       500
# 4         P2       200
# 5         P3       400
# 6         P1       200
# 7         P2       300
# 8         P3       400

# %% [markdown]
# 25.	Lấy dữ liệu tại chỉ số (index) là 2
# df.iloc[2]

# %%
df.iloc[2]
# Out:
# User_ID       1001
# Product_ID      P3
# Purchase       300
# Name: 2, dtype: object

# %% [markdown]
# 26.	Lấy dữ liệu từ dòng đầu tiên đến dòng 9 dùng iloc
# df.iloc[:10]

# %%
df.iloc[:10]
# Out:
#    User_ID Product_ID  Purchase
# 0     1001         P1       100
# 1     1001         P2       200
# 2     1001         P3       300
# 3     1001         P4       500
# 4     1002         P2       200
# 5     1003         P3       400
# 6     1004         P1       200
# 7     1004         P2       300
# 8     1004         P3       400
# 9     1004         P4       500

# %% [markdown]
# 27.	Lấy dữ liệu từ dòng đầu tiên đến dòng 9 gồm các cột 4 đến cột 7 dùng iloc
# df.iloc[2:9,4:7]

# %%
df.iloc[:10,1:3]
# Out:
#   Product_ID  Purchase
# 0         P1       100
# 1         P2       200
# 2         P3       300
# 3         P4       500
# 4         P2       200
# 5         P3       400
# 6         P1       200
# 7         P2       300
# 8         P3       400
# 9         P4       500

# %% [markdown]
# 28.	Sắp xếp dữ liệu theo 1 cột tăng dần
# df.sort_values(by='SALES',ascending=True)

# %%
df.sort_values(by='Purchase', ascending=True)
# Out:
#     User_ID Product_ID  Purchase
# 0      1001         P1       100
# 10     1005         P1       100
# 1      1001         P2       200
# 4      1002         P2       200
# 6      1004         P1       200
# 11     1005         P2       200
# 2      1001         P3       300
# 7      1004         P2       300
# 12     1005         P3       300
# 5      1003         P3       400
# 8      1004         P3       400
# 13     1005         P4       400
# 3      1001         P4       500
# 9      1004         P4       500
# 14     1005         P5       500

# %% [markdown]
# 29.	Sắp xếp dữ liệu theo nhiều tiêu chí
# df.sort_values(by=['QUANTITYORDERED','PRICEEACH'],ascending=[True,False])

# %%
df.sort_values(by=['Purchase','Product_ID'], ascending=[True,False])
# Out:
#     User_ID Product_ID  Purchase
# 0      1001         P1       100
# 10     1005         P1       100
# 1      1001         P2       200
# 4      1002         P2       200
# 11     1005         P2       200
# 6      1004         P1       200
# 2      1001         P3       300
# 12     1005         P3       300
# 7      1004         P2       300
# 13     1005         P4       400
# 5      1003         P3       400
# 8      1004         P3       400
# 14     1005         P5       500
# 3      1001         P4       500
# 9      1004         P4       500

# %% [markdown]
# 30.	Lọc dữ liệu theo 1 điều kiện
# df[df[‘SALES']>5000]
# df.loc[df['SALES']>5000]

# %%
df[df['Purchase']>300]
# Out:
#     User_ID Product_ID  Purchase
# 3      1001         P4       500
# 5      1003         P3       400
# 8      1004         P3       400
# 9      1004         P4       500
# 13     1005         P4       400
# 14     1005         P5       500

# %%
df.loc[df['Purchase']>300]
# Out:
#     User_ID Product_ID  Purchase
# 3      1001         P4       500
# 5      1003         P3       400
# 8      1004         P3       400
# 9      1004         P4       500
# 13     1005         P4       400
# 14     1005         P5       500

# %% [markdown]
# 31.	Lọc dữ liệu theo nhiều điều kiện
# df[(df['SALES']>5000) & (df['QUANTITYORDERED']>40)]

# %%
df[(df['Purchase']>300) & (df['User_ID']>1000)]
# Out:
#     User_ID Product_ID  Purchase
# 3      1001         P4       500
# 5      1003         P3       400
# 8      1004         P3       400
# 9      1004         P4       500
# 13     1005         P4       400
# 14     1005         P5       500

# %% [markdown]
# 32.	Lọc giá trị và gán điều kiện dùng loc
# df.loc[df['PRICEEACH']>=65,'FLAG']='EXPENSIVE'
# df.loc[df['PRICEEACH']<65,'FLAG']='CHEAP'
# #df['FLAG']
# df[['PRICEEACH','FLAG']]#[:50]

# %%
df.loc[df['Purchase']>100,'User_ID']>1000
# Out:
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 11    True
# 12    True
# 13    True
# 14    True
# Name: User_ID, dtype: bool

# %%
df[['Purchase','User_ID']][:5]
# Out:
#    Purchase  User_ID
# 0       100     1001
# 1       200     1001
# 2       300     1001
# 3       500     1001
# 4       200     1002

# %% [markdown]
# 33.	Viết hàm trả về giá trị có nhiều điều kiện và áp dụng hàm gán trị trả về cho 1 cột
# def foo(x):
#     if x<10:
#         return 'BAD'
#     elif x>=10 and x<50:
#         return 'GOOD'
#     else:
#         return 'EXCELLENT'
# df['WORTH']=df[['QUANTITYORDERED']].applymap(foo)
#
# df[['QUANTITYORDERED','WORTH']]

# %%
def foo(x):
    if x<200:
        return 'BAD'
    elif x>=200 and x<500:
        return 'GOOD'
    else:
        return 'EXCELLENT'
df['Worth'] = df[['Purchase']].applymap(foo)
df
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_4856\3328701264.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df['Worth'] = df[['Purchase']].applymap(foo)
#     User_ID Product_ID  Purchase      Worth
# 0      1001         P1       100        BAD
# 1      1001         P2       200       GOOD
# 2      1001         P3       300       GOOD
# 3      1001         P4       500  EXCELLENT
# 4      1002         P2       200       GOOD
# 5      1003         P3       400       GOOD
# 6      1004         P1       200       GOOD
# 7      1004         P2       300       GOOD
# 8      1004         P3       400       GOOD
# 9      1004         P4       500  EXCELLENT
# 10     1005         P1       100        BAD
# 11     1005         P2       200       GOOD
# 12     1005         P3       300       GOOD
# 13     1005         P4       400       GOOD
# 14     1005         P5       500  EXCELLENT

# %% [markdown]
# 34.	Ánh xạ giá trị tới 1 cột
# dict_map ={1:'Qui_1',2:'Qui_2',3:'Qui_3',4:'Qui_4'}
# df['QTR_ID']=df['QTR_ID'].map(dict_map)
# df['QTR_ID']

# %%
dict_map ={100:'Qui_1',200:'Qui_2',300:'Qui_3',400:'Qui_4'}
df['QTR_ID']=df['Purchase'].map(dict_map)
df['QTR_ID']
# Out:
# 0     Qui_1
# 1     Qui_2
# 2     Qui_3
# 3       NaN
# 4     Qui_2
# 5     Qui_4
# 6     Qui_2
# 7     Qui_3
# 8     Qui_4
# 9       NaN
# 10    Qui_1
# 11    Qui_2
# 12    Qui_3
# 13    Qui_4
# 14      NaN
# Name: QTR_ID, dtype: object

# %%
df
# Out:
#     User_ID Product_ID  Purchase      Worth QTR_ID
# 0      1001         P1       100        BAD  Qui_1
# 1      1001         P2       200       GOOD  Qui_2
# 2      1001         P3       300       GOOD  Qui_3
# 3      1001         P4       500  EXCELLENT    NaN
# 4      1002         P2       200       GOOD  Qui_2
# 5      1003         P3       400       GOOD  Qui_4
# 6      1004         P1       200       GOOD  Qui_2
# 7      1004         P2       300       GOOD  Qui_3
# 8      1004         P3       400       GOOD  Qui_4
# 9      1004         P4       500  EXCELLENT    NaN
# 10     1005         P1       100        BAD  Qui_1
# 11     1005         P2       200       GOOD  Qui_2
# 12     1005         P3       300       GOOD  Qui_3
# 13     1005         P4       400       GOOD  Qui_4
# 14     1005         P5       500  EXCELLENT    NaN

# %% [markdown]
# 35.	Lấy những dòng dữ liệu bằng 1 điều kiện nào đó
# df[['QUANTITYORDERED','PRICEEACH']].loc[df['YEAR_ID']==2003]

# %%
df[['User_ID','Worth']].loc[df['Purchase'] > 100]
# Out:
#     User_ID      Worth
# 1      1001       GOOD
# 2      1001       GOOD
# 3      1001  EXCELLENT
# 4      1002       GOOD
# 5      1003       GOOD
# 6      1004       GOOD
# 7      1004       GOOD
# 8      1004       GOOD
# 9      1004  EXCELLENT
# 11     1005       GOOD
# 12     1005       GOOD
# 13     1005       GOOD
# 14     1005  EXCELLENT

# %% [markdown]
# 36.	Hiển thị các bản ghi có cột kiểu số hơn 25
# df[df[‘age’]<25]
# Tuoitre =df[df[‘age’]<25]
# Tuoitre[:5]

# %%
df[df['Purchase']<250]
a =df[df['Purchase']<250]
a[:5]
# Out:
#     User_ID Product_ID  Purchase Worth QTR_ID
# 0      1001         P1       100   BAD  Qui_1
# 1      1001         P2       200  GOOD  Qui_2
# 4      1002         P2       200  GOOD  Qui_2
# 6      1004         P1       200  GOOD  Qui_2
# 10     1005         P1       100   BAD  Qui_1

# %% [markdown]
# 37.	Sinh viên tự nghĩ ra các câu hỏi đọc dữ liệu theo các điều kiện và thực hiện lại các câu hòi đó. Yêu cầu sinh viên ghi lại và lệnh thực hiện các câu hòi đó.

# %%
dg = df[df['Worth'] == 'GOOD']
dg
# Out:
#     User_ID Product_ID  Purchase Worth QTR_ID
# 1      1001         P2       200  GOOD  Qui_2
# 2      1001         P3       300  GOOD  Qui_3
# 4      1002         P2       200  GOOD  Qui_2
# 5      1003         P3       400  GOOD  Qui_4
# 6      1004         P1       200  GOOD  Qui_2
# 7      1004         P2       300  GOOD  Qui_3
# 8      1004         P3       400  GOOD  Qui_4
# 11     1005         P2       200  GOOD  Qui_2
# 12     1005         P3       300  GOOD  Qui_3
# 13     1005         P4       400  GOOD  Qui_4

# %% [markdown]
# 38.	Thực hiện 1 ví dụ để lấy giá trị của một cột trả về dưới dạng numpy array trong thư viện pandas python.

# %%
df['Worth'].values
# Out:
# array(['BAD', 'GOOD', 'GOOD', 'EXCELLENT', 'GOOD', 'GOOD', 'GOOD', 'GOOD',
#        'GOOD', 'EXCELLENT', 'BAD', 'GOOD', 'GOOD', 'GOOD', 'EXCELLENT'],
#       dtype=object)

# %% [markdown]
# 39.	Sử dụng thư viện random để sinh ngẫu nhiên một list năm sinh và thêm vào dataframe.

# %%
df_len = len(df)
namsx = [random.randrange(2020,2023,1) for i in range(df_len)]
df['namsx'] = namsx
df.tail(5)
# Out:
#     User_ID Product_ID  Purchase      Worth QTR_ID  namsx
# 10     1005         P1       100        BAD  Qui_1   2022
# 11     1005         P2       200       GOOD  Qui_2   2022
# 12     1005         P3       300       GOOD  Qui_3   2020
# 13     1005         P4       400       GOOD  Qui_4   2020
# 14     1005         P5       500  EXCELLENT    NaN   2020

# %% [markdown]
# 40.	Thêm 1 cột vào file dữ liệu

# %%
df['Evaluate'] = df['Worth']
df.head(5)
# Out:
#    User_ID Product_ID  Purchase      Worth QTR_ID  namsx   Evaluate
# 0     1001         P1       100        BAD  Qui_1   2021        BAD
# 1     1001         P2       200       GOOD  Qui_2   2021       GOOD
# 2     1001         P3       300       GOOD  Qui_3   2022       GOOD
# 3     1001         P4       500  EXCELLENT    NaN   2021  EXCELLENT
# 4     1002         P2       200       GOOD  Qui_2   2021       GOOD

# %% [markdown]
# 41.	Thêm 1 cột vào dữ liệu theo tiêu chí nếu điều kiện thoả thì giá trị mặc định là True, ngược lại là False.

# %%
df['ToT'] = df['Worth'] == 'GOOD'
df.head(5)
# Out:
#    User_ID Product_ID  Purchase      Worth QTR_ID  namsx   Evaluate    ToT
# 0     1001         P1       100        BAD  Qui_1   2021        BAD  False
# 1     1001         P2       200       GOOD  Qui_2   2021       GOOD   True
# 2     1001         P3       300       GOOD  Qui_3   2022       GOOD   True
# 3     1001         P4       500  EXCELLENT    NaN   2021  EXCELLENT  False
# 4     1002         P2       200       GOOD  Qui_2   2021       GOOD   True

# %% [markdown]
# 42.	Tạo 1 cột mới có giá trị rỗng

# %%
df['TONGTIEN'] = None
df
# Out:
#     User_ID Product_ID  Purchase      Worth QTR_ID  namsx   Evaluate    ToT  \
# 0      1001         P1       100        BAD  Qui_1   2021        BAD  False
# 1      1001         P2       200       GOOD  Qui_2   2021       GOOD   True
# 2      1001         P3       300       GOOD  Qui_3   2022       GOOD   True
# 3      1001         P4       500  EXCELLENT    NaN   2021  EXCELLENT  False
# 4      1002         P2       200       GOOD  Qui_2   2021       GOOD   True
# 5      1003         P3       400       GOOD  Qui_4   2020       GOOD   True
# 6      1004         P1       200       GOOD  Qui_2   2020       GOOD   True
# 7      1004         P2       300       GOOD  Qui_3   2021       GOOD   True
# 8      1004         P3       400       GOOD  Qui_4   2020       GOOD   True
# 9      1004         P4       500  EXCELLENT    NaN   2021  EXCELLENT  False
# 10     1005         P1       100        BAD  Qui_1   2022        BAD  False
# 11     1005         P2       200       GOOD  Qui_2   2022       GOOD   True
# 12     1005         P3       300       GOOD  Qui_3   2020       GOOD   True
# 13     1005         P4       400       GOOD  Qui_4   2020       GOOD   True
# 14     1005         P5       500  EXCELLENT    NaN   2020  EXCELLENT  False
#
#    TONGTIEN
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None

# %% [markdown]
# 43.	Thêm 1 bản ghi trong dataframe

# %%
df.loc[15] = {'User_ID':'1003','Product_ID':'P5','Purchase':400,
              'Worth':'GOOD','QTR_ID':'Qui_4','namsx':2020,'Evaluate':'GOOD','ToT':True,'TONGTIEN':None}

# %%
df
# Out:
#    User_ID Product_ID  Purchase      Worth QTR_ID  namsx   Evaluate    ToT  \
# 0     1001         P1       100        BAD  Qui_1   2021        BAD  False
# 1     1001         P2       200       GOOD  Qui_2   2021       GOOD   True
# 2     1001         P3       300       GOOD  Qui_3   2022       GOOD   True
# 3     1001         P4       500  EXCELLENT    NaN   2021  EXCELLENT  False
# 4     1002         P2       200       GOOD  Qui_2   2021       GOOD   True
# 5     1003         P3       400       GOOD  Qui_4   2020       GOOD   True
# 6     1004         P1       200       GOOD  Qui_2   2020       GOOD   True
# 7     1004         P2       300       GOOD  Qui_3   2021       GOOD   True
# 8     1004         P3       400       GOOD  Qui_4   2020       GOOD   True
# 9     1004         P4       500  EXCELLENT    NaN   2021  EXCELLENT  False
# 10    1005         P1       100        BAD  Qui_1   2022        BAD  False
# 11    1005         P2       200       GOOD  Qui_2   2022       GOOD   True
# 12    1005         P3       300       GOOD  Qui_3   2020       GOOD   True
# 13    1005         P4       400       GOOD  Qui_4   2020       GOOD   True
# 14    1005         P5       500  EXCELLENT    NaN   2020  EXCELLENT  False
# 15    1003         P5       400       GOOD  Qui_4   2020       GOOD   True
#
#    TONGTIEN
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None

# %% [markdown]
# 44.	Sửa giá trị của cột

# %%
df['QTR_ID'] = None
df
# Out:
#    User_ID Product_ID  Purchase      Worth QTR_ID  namsx   Evaluate    ToT  \
# 0     1001         P1       100        BAD   None   2021        BAD  False
# 1     1001         P2       200       GOOD   None   2021       GOOD   True
# 2     1001         P3       300       GOOD   None   2022       GOOD   True
# 3     1001         P4       500  EXCELLENT   None   2021  EXCELLENT  False
# 4     1002         P2       200       GOOD   None   2021       GOOD   True
# 5     1003         P3       400       GOOD   None   2020       GOOD   True
# 6     1004         P1       200       GOOD   None   2020       GOOD   True
# 7     1004         P2       300       GOOD   None   2021       GOOD   True
# 8     1004         P3       400       GOOD   None   2020       GOOD   True
# 9     1004         P4       500  EXCELLENT   None   2021  EXCELLENT  False
# 10    1005         P1       100        BAD   None   2022        BAD  False
# 11    1005         P2       200       GOOD   None   2022       GOOD   True
# 12    1005         P3       300       GOOD   None   2020       GOOD   True
# 13    1005         P4       400       GOOD   None   2020       GOOD   True
# 14    1005         P5       500  EXCELLENT   None   2020  EXCELLENT  False
# 15    1003         P5       400       GOOD   None   2020       GOOD   True
#
#    TONGTIEN
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None

# %% [markdown]
# 45.	Xóa cột trong dataframe

# %%
df = df.drop(['namsx'],axis=1)
df
# Out:
#    User_ID Product_ID  Purchase      Worth QTR_ID   Evaluate    ToT TONGTIEN
# 0     1001         P1       100        BAD   None        BAD  False     None
# 1     1001         P2       200       GOOD   None       GOOD   True     None
# 2     1001         P3       300       GOOD   None       GOOD   True     None
# 3     1001         P4       500  EXCELLENT   None  EXCELLENT  False     None
# 4     1002         P2       200       GOOD   None       GOOD   True     None
# 5     1003         P3       400       GOOD   None       GOOD   True     None
# 6     1004         P1       200       GOOD   None       GOOD   True     None
# 7     1004         P2       300       GOOD   None       GOOD   True     None
# 8     1004         P3       400       GOOD   None       GOOD   True     None
# 9     1004         P4       500  EXCELLENT   None  EXCELLENT  False     None
# 10    1005         P1       100        BAD   None        BAD  False     None
# 11    1005         P2       200       GOOD   None       GOOD   True     None
# 12    1005         P3       300       GOOD   None       GOOD   True     None
# 13    1005         P4       400       GOOD   None       GOOD   True     None
# 14    1005         P5       500  EXCELLENT   None  EXCELLENT  False     None
# 15    1003         P5       400       GOOD   None       GOOD   True     None

# %% [markdown]
# 46.	Xóa bản ghi theo chỉ số

# %%
df = df.drop([0,1])
df
# Out:
#    User_ID Product_ID  Purchase      Worth QTR_ID   Evaluate    ToT TONGTIEN
# 2     1001         P3       300       GOOD   None       GOOD   True     None
# 3     1001         P4       500  EXCELLENT   None  EXCELLENT  False     None
# 4     1002         P2       200       GOOD   None       GOOD   True     None
# 5     1003         P3       400       GOOD   None       GOOD   True     None
# 6     1004         P1       200       GOOD   None       GOOD   True     None
# 7     1004         P2       300       GOOD   None       GOOD   True     None
# 8     1004         P3       400       GOOD   None       GOOD   True     None
# 9     1004         P4       500  EXCELLENT   None  EXCELLENT  False     None
# 10    1005         P1       100        BAD   None        BAD  False     None
# 11    1005         P2       200       GOOD   None       GOOD   True     None
# 12    1005         P3       300       GOOD   None       GOOD   True     None
# 13    1005         P4       400       GOOD   None       GOOD   True     None
# 14    1005         P5       500  EXCELLENT   None  EXCELLENT  False     None
# 15    1003         P5       400       GOOD   None       GOOD   True     None

# %% [markdown]
# 47.	Sử dụng hàm describe() để thống kê dữ liệu

# %%
df.describe()
# Out:
#          Purchase
# count   14.000000
# mean   335.714286
# std    127.744594
# min    100.000000
# 25%    225.000000
# 50%    350.000000
# 75%    400.000000
# max    500.000000

# %% [markdown]
# 48.	Xem thống kê trên từng cột

# %%
df['Purchase'].value_counts()
# Out:
# Purchase
# 400    4
# 300    3
# 500    3
# 200    3
# 100    1
# Name: count, dtype: int64

# %% [markdown]
# 49.	Vẽ đồ thị xem phân bổ giá trị của 1 trường trong dataframe

# %%
a = df['Purchase'].value_counts().plot(kind='bar')

# %% [markdown]
# 50.	Tạo mới dataframe từ các python list

# %%
txts = ['chỗ này ăn cũng khá ngon','ngon, nhất định sẽ quay lại','thái độ phục vụ quá tệ']
labels = [1,1,0]
df1 = pd.DataFrame()
df1['txt'] = txts
df1['label'] = labels
df1
# Out:
#                            txt  label
# 0     chỗ này ăn cũng khá ngon      1
# 1  ngon, nhất định sẽ quay lại      1
# 2       thái độ phục vụ quá tệ      0

# %% [markdown]
# 51.	Sắp xếp dataframe

# %%
print('Trước khi sắp xếp')
df
# Out:
# Trước khi sắp xếp
#    User_ID Product_ID  Purchase      Worth QTR_ID   Evaluate    ToT TONGTIEN
# 2     1001         P3       300       GOOD   None       GOOD   True     None
# 3     1001         P4       500  EXCELLENT   None  EXCELLENT  False     None
# 4     1002         P2       200       GOOD   None       GOOD   True     None
# 5     1003         P3       400       GOOD   None       GOOD   True     None
# 6     1004         P1       200       GOOD   None       GOOD   True     None
# 7     1004         P2       300       GOOD   None       GOOD   True     None
# 8     1004         P3       400       GOOD   None       GOOD   True     None
# 9     1004         P4       500  EXCELLENT   None  EXCELLENT  False     None
# 10    1005         P1       100        BAD   None        BAD  False     None
# 11    1005         P2       200       GOOD   None       GOOD   True     None
# 12    1005         P3       300       GOOD   None       GOOD   True     None
# 13    1005         P4       400       GOOD   None       GOOD   True     None
# 14    1005         P5       500  EXCELLENT   None  EXCELLENT  False     None
# 15    1003         P5       400       GOOD   None       GOOD   True     None

# %%
df = df.sort_values('Purchase', ascending=True)
print('Sau khi sắp xếp')
df
# Out:
# Sau khi sắp xếp
#    User_ID Product_ID  Purchase      Worth QTR_ID   Evaluate    ToT TONGTIEN
# 10    1005         P1       100        BAD   None        BAD  False     None
# 4     1002         P2       200       GOOD   None       GOOD   True     None
# 6     1004         P1       200       GOOD   None       GOOD   True     None
# 11    1005         P2       200       GOOD   None       GOOD   True     None
# 2     1001         P3       300       GOOD   None       GOOD   True     None
# 7     1004         P2       300       GOOD   None       GOOD   True     None
# 12    1005         P3       300       GOOD   None       GOOD   True     None
# 5     1003         P3       400       GOOD   None       GOOD   True     None
# 8     1004         P3       400       GOOD   None       GOOD   True     None
# 13    1005         P4       400       GOOD   None       GOOD   True     None
# 15    1003         P5       400       GOOD   None       GOOD   True     None
# 3     1001         P4       500  EXCELLENT   None  EXCELLENT  False     None
# 9     1004         P4       500  EXCELLENT   None  EXCELLENT  False     None
# 14    1005         P5       500  EXCELLENT   None  EXCELLENT  False     None

# %% [markdown]
# 52.	Nối 2 dataframe (Lỗi)

# %%
df_1 = pd.DataFrame({'name':['Hiếu'], 'age':[18], 'gender':['male']})
df_2 = pd.DataFrame({'name': ['Nam','Mai','Hoa'], 'age':[15,17,19]})
df_1 = pd.concat([df_1,df_2], ignore_index=True)
df_3 = df_1
df_3
# Out:
#    name  age gender
# 0  Hiếu   18   male
# 1   Nam   15    NaN
# 2   Mai   17    NaN
# 3   Hoa   19    NaN

# %% [markdown]
# 53.	Xáo trộn các bản ghi trong dataframe

# %%
df1 = pd.DataFrame({'name':['Hiếu','Nam','Mai','Hoa'], 'age':[18,15,17,19]})
print('Before shuffle\n', df1)
df1 = df1.sample(frac=1).reset_index(drop=True)
print('After shuffle\n', df1)
# Out:
# Before shuffle
#     name  age
# 0  Hiếu   18
# 1   Nam   15
# 2   Mai   17
# 3   Hoa   19
# After shuffle
#     name  age
# 0   Nam   15
# 1  Hiếu   18
# 2   Mai   17
# 3   Hoa   19

# %% [markdown]
# 54.	Lưu dataframe về file csv

# %%
df1.to_csv('KHACHHANG.csv')

# %% [markdown]
# 55.	Tối ưu bộ nhớ khi dùng pandas

# %%
import numpy as np
import pandas as pd

def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage og dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object and col_type.name != 'category' and 'datetime' not in col_type.name:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        elif 'datetime' not in col_type.name:
            df[col] = df[col].astype('category')
    
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased bt {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df
reduce_mem_usage(df)
